# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('carclaims.csv')

# %%
df
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday    Honda        Urban          Tuesday
# 1       Jan            3  Wednesday    Honda        Urban           Monday
# 2       Oct            5     Friday    Honda        Urban         Thursday
# 3       Jun            2   Saturday   Toyota        Rural           Friday
# 4       Jan            5     Monday    Honda        Urban          Tuesday
# ...     ...          ...        ...      ...          ...              ...
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# 0              Jan                   1  Female        Single  ...
# 1              Jan                   4    Male        Single  ...
# 2              Nov                   2    Male       Married  ...
# 3              Jul                   1    Male       Married  ...
# 4              Feb                   2  Female        Single  ...
# ...            ...                 ...     ...           ...  ...
# 15415          Nov                   5    Male       Married  ...
# 15416          Dec                   1    Male       Married  ...
# 15417          Dec                   1    Male        Single  ...
# 15418          Dec                   2  Female       Married  ...
# 15419          Dec                   3    Male        Single  ...
#
#        AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0               26 to 30                No             No  External
# 1               31 to 35               Yes             No  External
# 2               41 to 50                No             No  External
# 3               51 to 65               Yes             No  External
# 4               31 to 35                No             No  External
# ...                  ...               ...            ...       ...
# 15415           31 to 35                No             No  External
# 15416           31 to 35                No             No  External
# 15417           26 to 30                No             No  External
# 15418           31 to 35                No             No  External
# 15419           26 to 30                No             No  External
#
#       NumberOfSuppliments  AddressChange-Claim  NumberOfCars  Year  \
# 0                    none               1 year        3 to 4  1994
# 1                    none            no change     1 vehicle  1994
# 2                    none            no change     1 vehicle  1994
# 3             more than 5            no change     1 vehicle  1994
# 4                    none            no change     1 vehicle  1994
# ...                   ...                  ...           ...   ...
# 15415                none            no change     1 vehicle  1996
# 15416         more than 5            no change        3 to 4  1996
# 15417              1 to 2            no change     1 vehicle  1996
# 15418         more than 5            no change     1 vehicle  1996
# 15419              1 to 2            no change     1 vehicle  1996
#
#        BasePolicy FraudFound
# 0       Liability         No
# 1       Collision         No
# 2       Collision         No
# 3       Liability         No
# 4       Collision         No
# ...           ...        ...
# 15415   Collision        Yes
# 15416   Liability         No
# 15417   Collision        Yes
# 15418  All Perils         No
# 15419   Collision        Yes
#
# [15420 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days:Policy-Accident    0
# Days:Policy-Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange-Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# FraudFound              0
# dtype: int64

# %%
df.describe()
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  PolicyNumber  \
# count  15420.000000        15420.000000  15420.000000  15420.000000
# mean       2.788586            2.693969     39.855707   7710.500000
# std        1.287585            1.259115     13.492377   4451.514911
# min        1.000000            1.000000      0.000000      1.000000
# 25%        2.000000            2.000000     31.000000   3855.750000
# 50%        3.000000            3.000000     38.000000   7710.500000
# 75%        4.000000            4.000000     48.000000  11565.250000
# max        5.000000            5.000000     80.000000  15420.000000
#
#           RepNumber    Deductible  DriverRating          Year
# count  15420.000000  15420.000000  15420.000000  15420.000000
# mean       8.483268    407.704280      2.487808   1994.866472
# std        4.599948     43.950998      1.119453      0.803313
# min        1.000000    300.000000      1.000000   1994.000000
# 25%        5.000000    400.000000      1.000000   1994.000000
# 50%        8.000000    400.000000      2.000000   1995.000000
# 75%       12.000000    400.000000      3.000000   1996.000000
# max       16.000000    700.000000      4.000000   1996.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15420 non-null  object
#  1   WeekOfMonth           15420 non-null  int64
#  2   DayOfWeek             15420 non-null  object
#  3   Make                  15420 non-null  object
#  4   AccidentArea          15420 non-null  object
#  5   DayOfWeekClaimed      15420 non-null  object
#  6   MonthClaimed          15420 non-null  object
#  7   WeekOfMonthClaimed    15420 non-null  int64
#  8   Sex                   15420 non-null  object
#  9   MaritalStatus         15420 non-null  object
#  10  Age                   15420 non-null  int64
#  11  Fault                 15420 non-null  object
#  12  PolicyType            15420 non-null  object
#  13  VehicleCategory       15420 non-null  object
#  14  VehiclePrice          15420 non-null  object
#  15  PolicyNumber          15420 non-null  int64
#  16  RepNumber             15420 non-null  int64
#  17  Deductible            15420 non-null  int64
#  18  DriverRating          15420 non-null  int64
#  19  Days:Policy-Accident  15420 non-null  object
#  20  Days:Policy-Claim     15420 non-null  object
#  21  PastNumberOfClaims    15420 non-null  object
#  22  AgeOfVehicle          15420 non-null  object
#  23  AgeOfPolicyHolder     15420 non-null  object
#  24  PoliceReportFiled     15420 non-null  object
#  25  WitnessPresent        15420 non-null  object
#  26  AgentType             15420 non-null  object
#  27  NumberOfSuppliments   15420 non-null  object
#  28  AddressChange-Claim   15420 non-null  object
#  29  NumberOfCars          15420 non-null  object
#  30  Year                  15420 non-null  int64
#  31  BasePolicy            15420 non-null  object
#  32  FraudFound            15420 non-null  object
# dtypes: int64(8), object(25)
# memory usage: 3.9+ MB

# %%
df.corr()
# Out:
#                     WeekOfMonth  WeekOfMonthClaimed       Age  PolicyNumber  \
# WeekOfMonth            1.000000            0.275400 -0.004810     -0.007797
# WeekOfMonthClaimed     0.275400            1.000000  0.001859      0.011665
# Age                   -0.004810            0.001859  1.000000      0.025944
# PolicyNumber          -0.007797            0.011665  0.025944      1.000000
# RepNumber              0.005283            0.008908 -0.007063      0.008990
# Deductible            -0.003993            0.005457  0.069420      0.002133
# DriverRating          -0.016817           -0.000048  0.001668     -0.012312
# Year                  -0.003906            0.012175  0.025197      0.936513
#
#                     RepNumber  Deductible  DriverRating      Year
# WeekOfMonth          0.005283   -0.003993     -0.016817 -0.003906
# WeekOfMonthClaimed   0.008908    0.005457     -0.000048  0.012175
# Age                 -0.007063    0.069420      0.001668  0.025197
# PolicyNumber         0.008990    0.002133     -0.012312  0.936513
# RepNumber            1.000000    0.000509      0.011031  0.009338
# Deductible           0.000509    1.000000      0.003886 -0.001170
# DriverRating         0.011031    0.003886      1.000000 -0.013890
# Year                 0.009338   -0.001170     -0.013890  1.000000

# %% [markdown]
# # Drop some common which not nessasary for  model

# %%
df.drop(['Make','WeekOfMonth','DayOfWeek','DayOfWeekClaimed','MonthClaimed','WeekOfMonthClaimed','MaritalStatus','PolicyNumber','Days:Policy-Accident','AddressChange-Claim','Year',],axis = 1, inplace = True)

# %%
df
# Out:
#       Month AccidentArea     Sex  Age          Fault          PolicyType  \
# 0       Dec        Urban  Female   21  Policy Holder   Sport - Liability
# 1       Jan        Urban    Male   34  Policy Holder   Sport - Collision
# 2       Oct        Urban    Male   47  Policy Holder   Sport - Collision
# 3       Jun        Rural    Male   65    Third Party   Sedan - Liability
# 4       Jan        Urban  Female   27    Third Party   Sport - Collision
# ...     ...          ...     ...  ...            ...                 ...
# 15415   Nov        Urban    Male   35  Policy Holder   Sedan - Collision
# 15416   Nov        Urban    Male   30  Policy Holder   Sedan - Liability
# 15417   Nov        Rural    Male   24  Policy Holder   Sedan - Collision
# 15418   Dec        Urban  Female   34    Third Party  Sedan - All Perils
# 15419   Dec        Urban    Male   21  Policy Holder   Sedan - Collision
#
#       VehicleCategory      VehiclePrice  RepNumber  Deductible  ...  \
# 0               Sport  more than 69,000         12         300  ...
# 1               Sport  more than 69,000         15         400  ...
# 2               Sport  more than 69,000          7         400  ...
# 3               Sport  20,000 to 29,000          4         400  ...
# 4               Sport  more than 69,000          3         400  ...
# ...               ...               ...        ...         ...  ...
# 15415           Sedan  20,000 to 29,000          5         400  ...
# 15416           Sport  30,000 to 39,000         11         400  ...
# 15417           Sedan  20,000 to 29,000          4         400  ...
# 15418           Sedan  20,000 to 29,000          6         400  ...
# 15419           Sedan  20,000 to 29,000          3         400  ...
#
#        PastNumberOfClaims AgeOfVehicle AgeOfPolicyHolder PoliceReportFiled  \
# 0                    none      3 years          26 to 30                No
# 1                    none      6 years          31 to 35               Yes
# 2                       1      7 years          41 to 50                No
# 3                       1  more than 7          51 to 65               Yes
# 4                    none      5 years          31 to 35                No
# ...                   ...          ...               ...               ...
# 15415              2 to 4      6 years          31 to 35                No
# 15416         more than 4      6 years          31 to 35                No
# 15417         more than 4      5 years          26 to 30                No
# 15418                none      2 years          31 to 35                No
# 15419                none      5 years          26 to 30                No
#
#       WitnessPresent AgentType NumberOfSuppliments NumberOfCars  BasePolicy  \
# 0                 No  External                none       3 to 4   Liability
# 1                 No  External                none    1 vehicle   Collision
# 2                 No  External                none    1 vehicle   Collision
# 3                 No  External         more than 5    1 vehicle   Liability
# 4                 No  External                none    1 vehicle   Collision
# ...              ...       ...                 ...          ...         ...
# 15415             No  External                none    1 vehicle   Collision
# 15416             No  External         more than 5       3 to 4   Liability
# 15417             No  External              1 to 2    1 vehicle   Collision
# 15418             No  External         more than 5    1 vehicle  All Perils
# 15419             No  External              1 to 2    1 vehicle   Collision
#
#       FraudFound
# 0             No
# 1             No
# 2             No
# 3             No
# 4             No
# ...          ...
# 15415        Yes
# 15416         No
# 15417        Yes
# 15418         No
# 15419        Yes
#
# [15420 rows x 22 columns]

# %%
df['AgeOfVehicle'].unique()
# Out:
# array(['3 years', '6 years', '7 years', 'more than 7', '5 years', 'new',
#        '4 years', '2 years'], dtype=object)

# %%
df['PastNumberOfClaims'].unique()
# Out:
# array(['none', '1', '2 to 4', 'more than 4'], dtype=object)

# %%
 df['AgeOfPolicyHolder'].unique()
# Out:
# array(['26 to 30', '31 to 35', '41 to 50', '51 to 65', '21 to 25',
#        '36 to 40', '16 to 17', 'over 65', '18 to 20'], dtype=object)

# %%
df['AgeOfVehicle'].unique()
# Out:
# array(['3 years', '6 years', '7 years', 'more than 7', '5 years', 'new',
#        '4 years', '2 years'], dtype=object)

# %%
df['VehiclePrice'].unique()
# Out:
# array(['more than 69,000', '20,000 to 29,000', '30,000 to 39,000',
#        'less than 20,000', '40,000 to 59,000', '60,000 to 69,000'],
#       dtype=object)

# %%
df['NumberOfCars'].unique()
# Out:
# array(['3 to 4', '1 vehicle', '2 vehicles', '5 to 8', 'more than 8'],
#       dtype=object)

# %%
import seaborn as sns

# %% [markdown]
# # Multivariate analiysis

# %%
sns.pairplot(df, diag_kind='kde')

# %%
sns.barplot(df['Fault'],df['Age'] , hue = df['Sex'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fault', ylabel='Age'>

# %%
sns.catplot(x= 'Fault', y = 'PolicyType', data = df)

# %%
sns.stripplot(x= 'VehicleCategory',y = 'PolicyType', data = df)
# Out:
# <AxesSubplot:xlabel='VehicleCategory', ylabel='PolicyType'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(df['Deductible'],df['PolicyType'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deductible', ylabel='PolicyType'>

# %%
plt.figure(figsize=(5,5))
sns.boxplot(df['VehicleCategory'],df['DriverRating'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='VehicleCategory', ylabel='DriverRating'>

# %%
sns.stripplot(x= 'VehicleCategory',y = 'VehiclePrice', data = df)
# Out:
# <AxesSubplot:xlabel='VehicleCategory', ylabel='VehiclePrice'>

# %%
plt.figure(figsize=(20,10))

sns.stripplot(x= 'PoliceReportFiled',y = 'PolicyType', data = df)
# Out:
# <AxesSubplot:xlabel='PoliceReportFiled', ylabel='PolicyType'>

# %%
plt.figure(figsize=(20,10))
sns.stripplot(df['PolicyType'],df['AgeOfPolicyHolder'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PolicyType', ylabel='AgeOfPolicyHolder'>

# %%
sns.catplot(x = 'Fault', y = 'WitnessPresent',data = df)

# %%
df['AgeOfVehicle'] = df['AgeOfVehicle'].map({'3 years':3,'6 years':6,'7 years':7,'more than 7':8,'5 years':5,'new': 0, '4 years':4, '2 years':2})

# %%
df['PastNumberOfClaims'] = df['PastNumberOfClaims'].map({'none':1,'1':1,'2 to 4':4 , 'more than 4':5})

# %%
df['AgeOfPolicyHolder'] = df['AgeOfPolicyHolder'].map({'26 to 30':2,'31 to 35':3,'41 to 50':4,
                                                       '51 to 65':6,'21 to 25':1,'36 to 40':5,'16 to 17':0,'over 65':7,'18 to 20':0})

# %%
df['NumberOfCars'].unique()
# Out:
# array(['3 to 4', '1 vehicle', '2 vehicles', '5 to 8', 'more than 8'],
#       dtype=object)

# %%
#df['NumberOfCars']= df['NumberOfCars'].map({'3 to 4':3,'1 Vehicle':1,'2 vehicle':2,'5 to 8':7,'more than 8':9})

# %%
df['FraudFound'] = df['FraudFound'].map({'yes':1,'No':0})

# %%
df.drop(['Month'] , axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AccidentArea         15420 non-null  object
#  1   Sex                  15420 non-null  object
#  2   Age                  15420 non-null  int64
#  3   Fault                15420 non-null  object
#  4   PolicyType           15420 non-null  object
#  5   VehicleCategory      15420 non-null  object
#  6   VehiclePrice         15420 non-null  object
#  7   RepNumber            15420 non-null  int64
#  8   Deductible           15420 non-null  int64
#  9   DriverRating         15420 non-null  int64
#  10  Days:Policy-Claim    15420 non-null  object
#  11  PastNumberOfClaims   15420 non-null  int64
#  12  AgeOfVehicle         15420 non-null  int64
#  13  AgeOfPolicyHolder    15420 non-null  int64
#  14  PoliceReportFiled    15420 non-null  object
#  15  WitnessPresent       15420 non-null  object
#  16  AgentType            15420 non-null  object
#  17  NumberOfSuppliments  15420 non-null  object
#  18  NumberOfCars         15420 non-null  object
#  19  BasePolicy           15420 non-null  object
#  20  FraudFound           14497 non-null  float64
# dtypes: float64(1), int64(7), object(13)
# memory usage: 2.5+ MB

# %%
df.drop(['AccidentArea'],axis = 1, inplace = True)

# %%
df.drop(['VehicleCategory'],axis = 1, inplace= True)

# %%
df1 = pd.get_dummies(df, columns = ['Sex','PoliceReportFiled','Fault','PolicyType','WitnessPresent','AgentType','BasePolicy'],drop_first=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              15420 non-null  int64
#  1   VehiclePrice                     15420 non-null  object
#  2   RepNumber                        15420 non-null  int64
#  3   Deductible                       15420 non-null  int64
#  4   DriverRating                     15420 non-null  int64
#  5   Days:Policy-Claim                15420 non-null  object
#  6   PastNumberOfClaims               15420 non-null  int64
#  7   AgeOfVehicle                     15420 non-null  int64
#  8   AgeOfPolicyHolder                15420 non-null  int64
#  9   NumberOfSuppliments              15420 non-null  object
#  10  NumberOfCars                     15420 non-null  object
#  11  FraudFound                       14497 non-null  float64
#  12  Sex_Male                         15420 non-null  uint8
#  13  PoliceReportFiled_Yes            15420 non-null  uint8
#  14  Fault_Third Party                15420 non-null  uint8
#  15  PolicyType_Sedan - Collision     15420 non-null  uint8
#  16  PolicyType_Sedan - Liability     15420 non-null  uint8
#  17  PolicyType_Sport - All Perils    15420 non-null  uint8
#  18  PolicyType_Sport - Collision     15420 non-null  uint8
#  19  PolicyType_Sport - Liability     15420 non-null  uint8
#  20  PolicyType_Utility - All Perils  15420 non-null  uint8
#  21  PolicyType_Utility - Collision   15420 non-null  uint8
#  22  PolicyType_Utility - Liability   15420 non-null  uint8
#  23  WitnessPresent_Yes               15420 non-null  uint8
#  24  AgentType_Internal               15420 non-null  uint8
#  25  BasePolicy_Collision             15420 non-null  uint8
#  26  BasePolicy_Liability             15420 non-null  uint8
# dtypes: float64(1), int64(7), object(4), uint8(15)
# memory usage: 1.6+ MB

# %%
df1.corr()
# Out:
#                                       Age  RepNumber  Deductible  \
# Age                              1.000000  -0.007063    0.069420
# RepNumber                       -0.007063   1.000000    0.000509
# Deductible                       0.069420   0.000509    1.000000
# DriverRating                     0.001668   0.011031    0.003886
# PastNumberOfClaims              -0.028042  -0.001286    0.003980
# AgeOfVehicle                     0.682472  -0.005869    0.091614
# AgeOfPolicyHolder                0.854955  -0.001525    0.078519
# FraudFound                            NaN        NaN         NaN
# Sex_Male                         0.073113  -0.000833    0.014784
# PoliceReportFiled_Yes           -0.008346   0.006107    0.009005
# Fault_Third Party                0.009310  -0.006240   -0.002259
# PolicyType_Sedan - Collision    -0.061969  -0.011780   -0.012958
# PolicyType_Sedan - Liability    -0.016198   0.003072    0.019490
# PolicyType_Sport - All Perils   -0.017679   0.016199    0.005102
# PolicyType_Sport - Collision    -0.045496  -0.004004   -0.013721
# PolicyType_Sport - Liability    -0.011255   0.006157   -0.019736
# PolicyType_Utility - All Perils  0.055779   0.004579    0.011863
# PolicyType_Utility - Collision   0.031015   0.010079    0.002306
# PolicyType_Utility - Liability   0.004566   0.000708   -0.006474
# WitnessPresent_Yes              -0.007280   0.007521    0.000586
# AgentType_Internal              -0.000319   0.005630   -0.004244
# BasePolicy_Collision            -0.072228  -0.011935   -0.016765
# BasePolicy_Liability            -0.016014   0.003231    0.018619
#
#                                  DriverRating  PastNumberOfClaims  \
# Age                                  0.001668           -0.028042
# RepNumber                            0.011031           -0.001286
# Deductible                           0.003886            0.003980
# DriverRating                         1.000000           -0.001737
# PastNumberOfClaims                  -0.001737            1.000000
# AgeOfVehicle                        -0.002418           -0.003478
# AgeOfPolicyHolder                    0.003380           -0.015889
# FraudFound                                NaN                 NaN
# Sex_Male                            -0.002788           -0.001799
# PoliceReportFiled_Yes                0.015947           -0.001636
# Fault_Third Party                   -0.010277           -0.121009
# PolicyType_Sedan - Collision        -0.008549           -0.101078
# PolicyType_Sedan - Liability         0.000409            0.348929
# PolicyType_Sport - All Perils       -0.005728            0.005222
# PolicyType_Sport - Collision         0.000485           -0.097395
# PolicyType_Sport - Liability        -0.010704           -0.007695
# PolicyType_Utility - All Perils      0.009526            0.020696
# PolicyType_Utility - Collision       0.007054            0.018896
# PolicyType_Utility - Liability      -0.009809            0.008083
# WitnessPresent_Yes                   0.010489           -0.015209
# AgentType_Internal                  -0.000262            0.000052
# BasePolicy_Collision                -0.007651           -0.127752
# BasePolicy_Liability                -0.000548            0.349034
#
#                                  AgeOfVehicle  AgeOfPolicyHolder  FraudFound  \
# Age                                  0.682472           0.854955         NaN
# RepNumber                           -0.005869          -0.001525         NaN
# Deductible                           0.091614           0.078519         NaN
# DriverRating                        -0.002418           0.003380         NaN
# PastNumberOfClaims                  -0.003478          -0.015889         NaN
# AgeOfVehicle                         1.000000           0.661278         NaN
# AgeOfPolicyHolder                    0.661278           1.000000         NaN
# FraudFound                                NaN                NaN         NaN
# Sex_Male                             0.102660           0.057942         NaN
# PoliceReportFiled_Yes               -0.001556          -0.011701         NaN
# Fault_Third Party                    0.027789          -0.000550         NaN
# PolicyType_Sedan - Collision        -0.004454          -0.051875         NaN
# PolicyType_Sedan - Liability        -0.010468           0.001904         NaN
# PolicyType_Sport - All Perils       -0.054700          -0.022487         NaN
# PolicyType_Sport - Collision        -0.062647          -0.067705         NaN
# PolicyType_Sport - Liability        -0.019213          -0.011784         NaN
# PolicyType_Utility - All Perils      0.047734           0.054489         NaN
# PolicyType_Utility - Collision       0.019168           0.027313         NaN
# PolicyType_Utility - Liability       0.007950           0.010570         NaN
# WitnessPresent_Yes                  -0.008419          -0.002707         NaN
# AgentType_Internal                   0.020840           0.003866         NaN
# BasePolicy_Collision                -0.021768          -0.069375         NaN
# BasePolicy_Liability                -0.010160           0.002531         NaN
#
#                                  Sex_Male  PoliceReportFiled_Yes  ...  \
# Age                              0.073113              -0.008346  ...
# RepNumber                       -0.000833               0.006107  ...
# Deductible                       0.014784               0.009005  ...
# DriverRating                    -0.002788               0.015947  ...
# PastNumberOfClaims              -0.001799              -0.001636  ...
# AgeOfVehicle                     0.102660              -0.001556  ...
# AgeOfPolicyHolder                0.057942              -0.011701  ...
# FraudFound                            NaN                    NaN  ...
# Sex_Male                         1.000000              -0.007413  ...
# PoliceReportFiled_Yes           -0.007413               1.000000  ...
# Fault_Third Party                0.000230               0.027246  ...
# PolicyType_Sedan - Collision    -0.000984               0.034506  ...
# PolicyType_Sedan - Liability    -0.062638              -0.040863  ...
# PolicyType_Sport - All Perils    0.011585               0.014531  ...
# PolicyType_Sport - Collision     0.018744               0.000906  ...
# PolicyType_Sport - Liability    -0.018665              -0.001361  ...
# PolicyType_Utility - All Perils  0.063571              -0.006552  ...
# PolicyType_Utility - Collision   0.019049               0.001499  ...
# PolicyType_Utility - Liability   0.015933              -0.006240  ...
# WitnessPresent_Yes              -0.005585               0.198096  ...
# AgentType_Internal               0.012681               0.023268  ...
# BasePolicy_Collision             0.006469               0.034467  ...
# BasePolicy_Liability            -0.061632              -0.041331  ...
#
#                                  PolicyType_Sport - All Perils  \
# Age                                                  -0.017679
# RepNumber                                             0.016199
# Deductible                                            0.005102
# DriverRating                                         -0.005728
# PastNumberOfClaims                                    0.005222
# AgeOfVehicle                                         -0.054700
# AgeOfPolicyHolder                                    -0.022487
# FraudFound                                                 NaN
# Sex_Male                                              0.011585
# PoliceReportFiled_Yes                                 0.014531
# Fault_Third Party                                    -0.003777
# PolicyType_Sedan - Collision                         -0.028480
# PolicyType_Sedan - Liability                         -0.026133
# PolicyType_Sport - All Perils                         1.000000
# PolicyType_Sport - Collision                         -0.005744
# PolicyType_Sport - Liability                         -0.000304
# PolicyType_Utility - All Perils                      -0.005676
# PolicyType_Utility - Collision                       -0.001669
# PolicyType_Utility - Liability                       -0.001396
# WitnessPresent_Yes                                   -0.002847
# AgentType_Internal                                   -0.004763
# BasePolicy_Collision                                 -0.030011
# BasePolicy_Liability                                 -0.026219
#
#                                  PolicyType_Sport - Collision  \
# Age                                                 -0.045496
# RepNumber                                           -0.004004
# Deductible                                          -0.013721
# DriverRating                                         0.000485
# PastNumberOfClaims                                  -0.097395
# AgeOfVehicle                                        -0.062647
# AgeOfPolicyHolder                                   -0.067705
# FraudFound                                                NaN
# Sex_Male                                             0.018744
# PoliceReportFiled_Yes                                0.000906
# Fault_Third Party                                    0.082882
# PolicyType_Sedan - Collision                        -0.114490
# PolicyType_Sedan - Liability                        -0.105056
# PolicyType_Sport - All Perils                       -0.005744
# PolicyType_Sport - Collision                         1.000000
# PolicyType_Sport - Liability                        -0.001224
# PolicyType_Utility - All Perils                     -0.022816
# PolicyType_Utility - Collision                      -0.006709
# PolicyType_Utility - Liability                      -0.005611
# WitnessPresent_Yes                                   0.035191
# AgentType_Internal                                  -0.019147
# BasePolicy_Collision                                 0.191385
# BasePolicy_Liability                                -0.105398
#
#                                  PolicyType_Sport - Liability  \
# Age                                                 -0.011255
# RepNumber                                            0.006157
# Deductible                                          -0.019736
# DriverRating                                        -0.010704
# PastNumberOfClaims                                  -0.007695
# AgeOfVehicle                                        -0.019213
# AgeOfPolicyHolder                                   -0.011784
# FraudFound                                                NaN
# Sex_Male                                            -0.018665
# PoliceReportFiled_Yes                               -0.001361
# Fault_Third Party                                   -0.004919
# PolicyType_Sedan - Collision                        -0.006068
# PolicyType_Sedan - Liability                        -0.005568
# PolicyType_Sport - All Perils                       -0.000304
# PolicyType_Sport - Collision                        -0.001224
# PolicyType_Sport - Liability                         1.000000
# PolicyType_Utility - All Perils                     -0.001209
# PolicyType_Utility - Collision                      -0.000356
# PolicyType_Utility - Liability                      -0.000297
# WitnessPresent_Yes                                  -0.000607
# AgentType_Internal                                  -0.001015
# BasePolicy_Collision                                -0.006394
# BasePolicy_Liability                                 0.011610
#
#                                  PolicyType_Utility - All Perils  \
# Age                                                     0.055779
# RepNumber                                               0.004579
# Deductible                                              0.011863
# DriverRating                                            0.009526
# PastNumberOfClaims                                      0.020696
# AgeOfVehicle                                            0.047734
# AgeOfPolicyHolder                                       0.054489
# FraudFound                                                   NaN
# Sex_Male                                                0.063571
# PoliceReportFiled_Yes                                  -0.006552
# Fault_Third Party                                      -0.058957
# PolicyType_Sedan - Collision                           -0.113136
# PolicyType_Sedan - Liability                           -0.103814
# PolicyType_Sport - All Perils                          -0.005676
# PolicyType_Sport - Collision                           -0.022816
# PolicyType_Sport - Liability                           -0.001209
# PolicyType_Utility - All Perils                         1.000000
# PolicyType_Utility - Collision                         -0.006629
# PolicyType_Utility - Liability                         -0.005545
# WitnessPresent_Yes                                      0.006378
# AgentType_Internal                                     -0.018920
# BasePolicy_Collision                                   -0.119216
# BasePolicy_Liability                                   -0.104152
#
#                                  PolicyType_Utility - Collision  \
# Age                                                    0.031015
# RepNumber                                              0.010079
# Deductible                                             0.002306
# DriverRating                                           0.007054
# PastNumberOfClaims                                     0.018896
# AgeOfVehicle                                           0.019168
# AgeOfPolicyHolder                                      0.027313
# FraudFound                                                  NaN
# Sex_Male                                               0.019049
# PoliceReportFiled_Yes                                  0.001499
# Fault_Third Party                                     -0.023660
# PolicyType_Sedan - Collision                          -0.033266
# PolicyType_Sedan - Liability                          -0.030525
# PolicyType_Sport - All Perils                         -0.001669
# PolicyType_Sport - Collision                          -0.006709
# PolicyType_Sport - Liability                          -0.000356
# PolicyType_Utility - All Perils                       -0.006629
# PolicyType_Utility - Collision                         1.000000
# PolicyType_Utility - Liability                        -0.001630
# WitnessPresent_Yes                                    -0.003326
# AgentType_Internal                                    -0.005563
# BasePolicy_Collision                                   0.055609
# BasePolicy_Liability                                  -0.030625
#
#                                  PolicyType_Utility - Liability  \
# Age                                                    0.004566
# RepNumber                                              0.000708
# Deductible                                            -0.006474
# DriverRating                                          -0.009809
# PastNumberOfClaims                                     0.008083
# AgeOfVehicle                                           0.007950
# AgeOfPolicyHolder                                      0.010570
# FraudFound                                                  NaN
# Sex_Male                                               0.015933
# PoliceReportFiled_Yes                                 -0.006240
# Fault_Third Party                                     -0.014651
# PolicyType_Sedan - Collision                          -0.027824
# PolicyType_Sedan - Liability                          -0.025532
# PolicyType_Sport - All Perils                         -0.001396
# PolicyType_Sport - Collision                          -0.005611
# PolicyType_Sport - Liability                          -0.000297
# PolicyType_Utility - All Perils                       -0.005545
# PolicyType_Utility - Collision                        -0.001630
# PolicyType_Utility - Liability                         1.000000
# WitnessPresent_Yes                                    -0.002782
# AgentType_Internal                                     0.052057
# BasePolicy_Collision                                  -0.029320
# BasePolicy_Liability                                   0.053240
#
#                                  WitnessPresent_Yes  AgentType_Internal  \
# Age                                       -0.007280           -0.000319
# RepNumber                                  0.007521            0.005630
# Deductible                                 0.000586           -0.004244
# DriverRating                               0.010489           -0.000262
# PastNumberOfClaims                        -0.015209            0.000052
# AgeOfVehicle                              -0.008419            0.020840
# AgeOfPolicyHolder                         -0.002707            0.003866
# FraudFound                                      NaN                 NaN
# Sex_Male                                  -0.005585            0.012681
# PoliceReportFiled_Yes                      0.198096            0.023268
# Fault_Third Party                          0.061036            0.005306
# PolicyType_Sedan - Collision               0.009899            0.027988
# PolicyType_Sedan - Liability              -0.039122            0.051479
# PolicyType_Sport - All Perils             -0.002847           -0.004763
# PolicyType_Sport - Collision               0.035191           -0.019147
# PolicyType_Sport - Liability              -0.000607           -0.001015
# PolicyType_Utility - All Perils            0.006378           -0.018920
# PolicyType_Utility - Collision            -0.003326           -0.005563
# PolicyType_Utility - Liability            -0.002782            0.052057
# WitnessPresent_Yes                         1.000000            0.011450
# AgentType_Internal                         0.011450            1.000000
# BasePolicy_Collision                       0.020201            0.021279
# BasePolicy_Liability                      -0.039307            0.055502
#
#                                  BasePolicy_Collision  BasePolicy_Liability
# Age                                         -0.072228             -0.016014
# RepNumber                                   -0.011935              0.003231
# Deductible                                  -0.016765              0.018619
# DriverRating                                -0.007651             -0.000548
# PastNumberOfClaims                          -0.127752              0.349034
# AgeOfVehicle                                -0.021768             -0.010160
# AgeOfPolicyHolder                           -0.069375              0.002531
# FraudFound                                        NaN                   NaN
# Sex_Male                                     0.006469             -0.061632
# PoliceReportFiled_Yes                        0.034467             -0.041331
# Fault_Third Party                            0.057170             -0.197380
# PolicyType_Sedan - Collision                 0.949002             -0.522628
# PolicyType_Sedan - Liability                -0.548923              0.996749
# PolicyType_Sport - All Perils               -0.030011             -0.026219
# PolicyType_Sport - Collision                 0.191385             -0.105398
# PolicyType_Sport - Liability                -0.006394              0.011610
# PolicyType_Utility - All Perils             -0.119216             -0.104152
# PolicyType_Utility - Collision               0.055609             -0.030625
# PolicyType_Utility - Liability              -0.029320              0.053240
# WitnessPresent_Yes                           0.020201             -0.039307
# AgentType_Internal                           0.021279              0.055502
# BasePolicy_Collision                         1.000000             -0.550713
# BasePolicy_Liability                        -0.550713              1.000000
#
# [23 rows x 23 columns]

# %%
df1['Days:Policy-Claim'].unique()
# Out:
# array(['more than 30', '15 to 30', '8 to 15', 'none'], dtype=object)

# %%
df1['Days:Policy-Claim'] = df['Days:Policy-Claim'].map({'more than 30':35,'15 to 30':25,'8 to 15':12,'none':0})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              15420 non-null  int64
#  1   VehiclePrice                     15420 non-null  object
#  2   RepNumber                        15420 non-null  int64
#  3   Deductible                       15420 non-null  int64
#  4   DriverRating                     15420 non-null  int64
#  5   Days:Policy-Claim                15420 non-null  int64
#  6   PastNumberOfClaims               15420 non-null  int64
#  7   AgeOfVehicle                     15420 non-null  int64
#  8   AgeOfPolicyHolder                15420 non-null  int64
#  9   NumberOfSuppliments              15420 non-null  object
#  10  NumberOfCars                     15420 non-null  object
#  11  FraudFound                       14497 non-null  float64
#  12  Sex_Male                         15420 non-null  uint8
#  13  PoliceReportFiled_Yes            15420 non-null  uint8
#  14  Fault_Third Party                15420 non-null  uint8
#  15  PolicyType_Sedan - Collision     15420 non-null  uint8
#  16  PolicyType_Sedan - Liability     15420 non-null  uint8
#  17  PolicyType_Sport - All Perils    15420 non-null  uint8
#  18  PolicyType_Sport - Collision     15420 non-null  uint8
#  19  PolicyType_Sport - Liability     15420 non-null  uint8
#  20  PolicyType_Utility - All Perils  15420 non-null  uint8
#  21  PolicyType_Utility - Collision   15420 non-null  uint8
#  22  PolicyType_Utility - Liability   15420 non-null  uint8
#  23  WitnessPresent_Yes               15420 non-null  uint8
#  24  AgentType_Internal               15420 non-null  uint8
#  25  BasePolicy_Collision             15420 non-null  uint8
#  26  BasePolicy_Liability             15420 non-null  uint8
# dtypes: float64(1), int64(8), object(3), uint8(15)
# memory usage: 1.6+ MB

# %%
df1.drop(['NumberOfSuppliments'],axis = 1, inplace=True)

# %%
df1.drop(['VehiclePrice'],axis = 1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              15420 non-null  int64
#  1   RepNumber                        15420 non-null  int64
#  2   Deductible                       15420 non-null  int64
#  3   DriverRating                     15420 non-null  int64
#  4   Days:Policy-Claim                15420 non-null  int64
#  5   PastNumberOfClaims               15420 non-null  int64
#  6   AgeOfVehicle                     15420 non-null  int64
#  7   AgeOfPolicyHolder                15420 non-null  int64
#  8   NumberOfCars                     15420 non-null  object
#  9   FraudFound                       14497 non-null  float64
#  10  Sex_Male                         15420 non-null  uint8
#  11  PoliceReportFiled_Yes            15420 non-null  uint8
#  12  Fault_Third Party                15420 non-null  uint8
#  13  PolicyType_Sedan - Collision     15420 non-null  uint8
#  14  PolicyType_Sedan - Liability     15420 non-null  uint8
#  15  PolicyType_Sport - All Perils    15420 non-null  uint8
#  16  PolicyType_Sport - Collision     15420 non-null  uint8
#  17  PolicyType_Sport - Liability     15420 non-null  uint8
#  18  PolicyType_Utility - All Perils  15420 non-null  uint8
#  19  PolicyType_Utility - Collision   15420 non-null  uint8
#  20  PolicyType_Utility - Liability   15420 non-null  uint8
#  21  WitnessPresent_Yes               15420 non-null  uint8
#  22  AgentType_Internal               15420 non-null  uint8
#  23  BasePolicy_Collision             15420 non-null  uint8
#  24  BasePolicy_Liability             15420 non-null  uint8
# dtypes: float64(1), int64(8), object(1), uint8(15)
# memory usage: 1.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_NumberOfCars_ = LabelEncoder()

# %%
#df1['NumberOfCars_n'] = le_NumberOfCars_.fit_transform(df['NumberOfCars'])
df1.drop(['NumberOfCars'],axis = 1, inplace=True)

# %%
df1['FraudFound']=df1['FraudFound'].fillna(value = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              15420 non-null  int64
#  1   RepNumber                        15420 non-null  int64
#  2   Deductible                       15420 non-null  int64
#  3   DriverRating                     15420 non-null  int64
#  4   Days:Policy-Claim                15420 non-null  int64
#  5   PastNumberOfClaims               15420 non-null  int64
#  6   AgeOfVehicle                     15420 non-null  int64
#  7   AgeOfPolicyHolder                15420 non-null  int64
#  8   FraudFound                       15420 non-null  float64
#  9   Sex_Male                         15420 non-null  uint8
#  10  PoliceReportFiled_Yes            15420 non-null  uint8
#  11  Fault_Third Party                15420 non-null  uint8
#  12  PolicyType_Sedan - Collision     15420 non-null  uint8
#  13  PolicyType_Sedan - Liability     15420 non-null  uint8
#  14  PolicyType_Sport - All Perils    15420 non-null  uint8
#  15  PolicyType_Sport - Collision     15420 non-null  uint8
#  16  PolicyType_Sport - Liability     15420 non-null  uint8
#  17  PolicyType_Utility - All Perils  15420 non-null  uint8
#  18  PolicyType_Utility - Collision   15420 non-null  uint8
#  19  PolicyType_Utility - Liability   15420 non-null  uint8
#  20  WitnessPresent_Yes               15420 non-null  uint8
#  21  AgentType_Internal               15420 non-null  uint8
#  22  BasePolicy_Collision             15420 non-null  uint8
#  23  BasePolicy_Liability             15420 non-null  uint8
# dtypes: float64(1), int64(8), uint8(15)
# memory usage: 1.3 MB

# %%
from sklearn.model_selection import train_test_split

# %%
train = df1.drop('FraudFound',  axis = 1)
test = df1['FraudFound']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction = logreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.9378839590443686
